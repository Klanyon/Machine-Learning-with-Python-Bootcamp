# %% [markdown]
# <a href="https://colab.research.google.com/github/Klanyon/Machine-Learning-with-Python-Bootcamp/blob/main/WeekendAssignment_1%262.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 12-Using variable inside messages

# %%
product = "pepper"
cost = 150.50

print("One bag of", product, "costs", cost, "LRD")
# Out:
# One bag of pepper costs 150.5 LRD

# %% [markdown]
# Problem 11-Variable names vs. quoted strings

# %%
item = "Cassava"
price = 800
print(item)
print("item")
print(price)
print("price")
# Out:
# Cassava
# item
# 800
# price

# %% [markdown]
# Problem 10-Dsicount on a gallon of palm oil

# %%
Original_price = 2500
discount_rate = 0.10 #10%

discount_amount = Original_price * discount_rate
final_price = Original_price - discount_amount

print("Original price:", Original_price, "LRD")
print("Discount amount (10%):", discount_amount, "LRD")
print("Final Price after discount:", final_price, "LRD")
# Out:
# Original price: 2500 LRD
# Discount amount (10%): 250.0 LRD
# Final Price after discount: 2250.0 LRD

# %% [markdown]
# **Problem 9-Splitting Cost**

# %%
Cost_per_trader = 1800 / 3

print("Cost per trader when 3 traders share a 1800 LRD bag of rice onions:",
      Cost_per_trader, "LRD")
# Out:
# Cost per trader when 3 traders share a 1800 LRD bag of rice onions: 600.0 LRD

# %% [markdown]
# **Problem 8-Price Increase**

# %%
today_price = 3200
increase = 150
tomorrow_price = today_price + increase

print("Tomorrow rice price:", tomorrow_price, "LRD")
# Out:
# Tomorrow rice price: 3350 LRD

# %% [markdown]
# Part 3: Arithmetic with Variables.
# Problem 7- Total Revenue **bold text**

# %%
Price_per_bag = 800
quantity = 50
total_revenue = Price_per_bag * quantity

print("Total revenue for 25 bags of cassava:", total_revenue, "LRD")
# Out:
# Total revenue for 25 bags of cassava: 40000 LRD

# %% [markdown]
# **Problem 6**

# %%
has_scarity = False
is_rainy = True

print("Scarcity today:", has_scarity)
print("Rainy today:", is_rainy)
# Out:
# Scarcity today: False
# Rainy today: True

# %% [markdown]
# Problem 5

# %%
Current_price = 2550.75
quantity = 10
total_cost = Current_price * quantity

print("Total cost for", quantity, "bags:", total_cost, "LRD")
# Out:
# Total cost for 10 bags: 25507.5 LRD

# %% [markdown]
# Part 2: Creating Variables with Different Data Types. Problem 4

# %%
# Creating the four Variables
Market_name = "Gobachop Market"
Total_Market_table = 150
Price_per_bag = 3200.50
is_Market_open = True

# Printing each variavle with a label
print("Market name:", Market_name)
print("Total market tales:", Total_Market_table)
print("Price per bag:", Price_per_bag)
print("Is market open:", is_Market_open)

# Bonus: Print the type of each variable
print("\n---Data Type---")
print("Types of market_name:" , type(Market_name))
print("Type of total_market_table:", type(Total_Market_table))
print("Type of pric_per_bag:", type(Price_per_bag))
print("Type of is_market_open:", type(is_Market_open))
# Out:
# Market name: Gobachop Market
# Total market tales: 150
# Price per bag: 3200.5
# Is market open: True
#
# ---Data Type---
# Types of market_name: <class 'str'>
# Type of total_market_table: <class 'int'>
# Type of pric_per_bag: <class 'float'>
# Type of is_market_open: <class 'bool'>

# %% [markdown]
# Problem 2

# %%
Country = "Liberia"
print("Liberia", "became independent in", 1847)
# Out:
# Liberia became independent in 1847

# %% [markdown]
# Problem 3

# %%
print('The year is "1847"')
# Out:
# The year is "1847"

# %% [markdown]
#  Part 1: Variable vs. Quoted Text.
# Problem 1

# %%
Liberia = 1847
print(Liberia)
print("Liberia")

#Prints 1847 because Liberia is variable name that store the integer value 1847
#Prints Liberia because the quotes make it a string literal-the actual text "Liberia"
# Out:
# 1847
# Liberia

# %% [markdown]
# Assignment #2

# %% [markdown]
# Q#1 Type Conversion (The Nimba Truck Report)

# %%
# A. Convert transport_cost to an integer and calculate the total
transport_cost = "750"
car_loader_fee = 250

total_delivery_cost = int(transport_cost) + car_loader_fee

# B. Output the final report using an f-string

print(f"Ma Christiana, your final shipping cost is: {total_delivery_cost} LRD")
# Out:
# Ma Christiana, your final shipping cost is: 1000 LRD

# %% [markdown]
# Q#2 List and Matrices (Packing the Shipping Crate)

# %%
# A Machine Learning model is designed to process data in batches, much like a
# shipping truck that requires pallets rather than loose items.
# However, AI models are mathematically structured
# to perform calculations across entire datasets simultaneously.

# Packing the loose stock into a 2D matrix structure
loose_stock = [[45, 12, 88]] # using double brackets

# Adding the print command to output the result
print(loose_stock)
# Out:
# [[45, 12, 88]]

# %% [markdown]
# Q#3 Dictionaries (Tuning the Motorbike Engine)

# %%
# A. Creating the Dictionaries

yield_model_configs = {
    "engine_type": "Decision Tree",
    "max_depth_layers": 15,
    "strict_mode": True
}

# B. Outputting the f-string

print(f"System Check: Truning engine depth to {yield_model_configs['max_depth_layers']} branches.")
# Out:
# System Check: Truning engine depth to 15 branches.

# %% [markdown]
# Q#4 Methods vs. Attributes (The Commercial Transport Truck)

# %%
import pandas as pd

gobachop_data =  pd.DataFrame({
    "Vendor": ["Ma Musu", "Sia", "Flomo"],
    "Sales": [4000, 9500, 1500]

})

# Part A - Attribute (no parentheses)
print("Shape:", gobachop_data.shape)

# Part B - Method (parentheses required)
print("\nTOP row:")
print(gobachop_data.head(1))
# Out:
# Shape: (3, 2)
#
# TOP row:
#     Vendor  Sales
# 0  Ma Musu   4000
