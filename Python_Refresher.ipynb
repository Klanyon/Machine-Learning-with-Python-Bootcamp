# %% [markdown]
# <a href="https://colab.research.google.com/github/Klanyon/Machine-Learning-with-Python-Bootcamp/blob/main/Python_Refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variable

# %%
# Create a labeled storae basket and a numeber inside
tomato_price = 150
pepper_price = 80

# Pull the value out of the basket
print(tomato_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Change tomato_price

# %%
tomato_price = 100
print(tomato_price)
# Out:
# 100

# %% [markdown]
# Variables (ML Anchor)

# %%
# --- THIS CLUES (Features grouped as X) ---
rainfall_mm = 45.2  # Clue 1
bags_available = 100  # Clue 2

# --- THE GOAL (Target labeled as y) ---
predicted_price = 3200  # What our AI calculates

print("Inputs (X):", rainfall_mm,"mm rain,", bags_available, "bags.")
print("Output (y):", predicted_price, "LRD.")
# Out:
# Inputs (X): 45.2 mm rain, 100 bags.
# Output (y): 3200 LRD.

# %% [markdown]
# UNDERSTANDING PRINT

# %%
Liberia = 1847
print("Liberia")
print(Liberia)
# Out:
# Liberia
# 1847

# %% [markdown]
# DATA TYPES

# %%
quantity = 50
price = 150.50
item_name = "tomato"
stall_is_open = True


print(type(quantity))  #
print(type(price))  #
print(type(item_name))  #
print(type(stall_is_open))  #
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Concatenation

# %%
print("Lionel" + " " + "Messi")
# Out:
# Lionel Messi

# %%
print("Lionel" + " " + str(304.5))
# Out:
# Lionel 304.5

# %% [markdown]
# LIST

# %%
goods = ["tomatoes", "pappers", "onions", "rice"]
print(goods)  # ['tomatoes', 'peppers', 'onions','rice']
print(goods[0]) # tomatoes
print(goods[2]) # onions
print(goods[0:2])
print(goods[-1])
# Out:
# ['tomatoes', 'pappers', 'onions', 'rice']
# tomatoes
# onions
# ['tomatoes', 'pappers']
# rice

# %%
census = [1,2,3,4,5]
print(len (census))
# Out:
# 5

# %% [markdown]
# LISTS (ML ANCHOR)

# %%
loose_list = [3100, 3200, 3150]

# ML-ready create: double brackets [[]]

create_matrix = [[3100], [3200], [3150]]

print("Rejected by AI:", loose_list)
print("Accepted by AI:", create_matrix)
# Out:
# Rejected by AI: [3100, 3200, 3150]
# Accepted by AI: [[3100], [3200], [3150]]

# %%
Cows = 5

print(f"I have {Cows} Cows")
# Out:
# I have 5 Cows

# %% [markdown]
# f-STRINGS FOR CLEAN REPROTING

# %%
model_accuracy = 0.9456
predicted_value = 3500

print(f"Ma Christiana, our market AI model is {model_accuracy:.1%} accurate.")
print(f"Predicted price for rice at Red Light is: {predicted_value} LRD.")
# Out:
# Ma Christiana, our market AI model is 94.6% accurate.
# Predicted price for rice at Red Light is: 3500 LRD.

# %%
print(f"Ma Christiana, our market AI model is {model_accuracy:.2%} accurate.")
print(f"Predicted price for rice at Red Light is: {predicted_value} LRD.")
# Out:
# Ma Christiana, our market AI model is 94.56% accurate.
# Predicted price for rice at Red Light is: 3500 LRD.

# %%
print(f"Ma Christiana, our market AI model is {model_accuracy:.3%} accurate.")
print(f"Predicted price for rice at Red Light is: {predicted_value} LRD.")
# Out:
# Ma Christiana, our market AI model is 94.560% accurate.
# Predicted price for rice at Red Light is: 3500 LRD.

# %% [markdown]
# DICTIONARIES

# %%
stall_prices = {
    "tomatoes": 150,
    "peppers": 80,
    "onions": 60
}

print(stall_prices["tomatoes"])  # 150 this is the price of tomatoes
print(stall_prices["onions"]) # 60 this is the price of opions
print(stall_prices["peppers"]) # 80 this is the price of peppers
# Out:
# 150
# 60
# 80

# %% [markdown]
# DICTIONARIES (ML ANCHOR)

# %%
model_settings = {
    "learning_rate": 0.001,
    "algorithm": "Random Forest",
    "number_of_trees": 100
}

print(f"Initializing {model_settings['algorithm']} engine...")
print(f"Running with {model_settings['number_of_trees']} trees.")
# Out:
# Initializing Random Forest engine...
# Running with 100 trees.

# %% [markdown]
# LIBRARIES (Importing Toolboxes)

# %%
import math

error_rate = 625
root_error = math.sqrt(error_rate)
print(f"Root Margin of Error: {root_error} LRD")  # 25.0
# Out:
# Root Margin of Error: 25.0 LRD

# %%
print("it's mine")
# Out:
# it's mine

# %% [markdown]
# Method vs. Attributes Assignment #2  Q#4 rehearser

# %%
import pandas as pd

gobachop_data = pd.DataFrame({
    "Vendor": ["Ma Musu", "Sia", "Flomo"],
    "Sales": [4000, 9500, 1500]
})

# Example of attributes: .shape tells us the size of the Dataframe
print("DataFrame Shape:", gobachop_data.shape)

# Example of Method: .head() show the first few rows
print(gobachop_data.head())

# Example of Method: .describe() gives statistics for numeric columns
print(gobachop_data.describe())
# Out:
# DataFrame Shape: (3, 2)
#     Vendor  Sales
# 0  Ma Musu   4000
# 1      Sia   9500
# 2    Flomo   1500
#              Sales
# count     3.000000
# mean   5000.000000
# std    4092.676386
# min    1500.000000
# 25%    2750.000000
# 50%    4000.000000
# 75%    6750.000000
# max    9500.000000
